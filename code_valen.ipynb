# %%
import musdb
import museval
import librosa
import librosa.display
import tensorflow as tf
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split
from IPython.display import Audio, display

mus = musdb.DB(root="/Users/lukasfrosslund/Downloads/musdb18")
# Out:
# Using TensorFlow backend.

# %%
example_track = mus[42]
print(example_track.name)
#Audio(example_track.audio.T, rate=example_track.rate)
# Out:
# James May - On The Line

# %%
vocal = example_track.targets['vocals']
#Audio(vocal.audio.T, rate=example_track.rate)

# %%
plt.subplot(3, 1, 2)
librosa.display.waveplot(example_track.audio.T, sr=example_track.rate)
plt.title('Stereo')
# Out:
# Text(0.5, 1.0, 'Stereo')

# %%
stft = librosa.stft(librosa.to_mono(example_track.audio.T))
librosa.display.specshow(librosa.amplitude_to_db(np.abs(stft), ref=np.max), y_axis='log', x_axis='time')
